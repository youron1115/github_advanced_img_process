# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
path=r"D:\4_Intensity Transformation and Spatial Filtering\im_11_pneumonia.jpg"

# %%
src=cv2.imread(path)

# %%
laplacian = cv2.Laplacian(src, cv2.CV_64F,ksize=3)

# %%
weight = 2.5
sharpened_image = src - (laplacian * weight)

# 步驟 3: 確保數值在 0-255 範圍內，並轉換回 uint8
sharpened_image = np.clip(sharpened_image, 0, 255).astype(np.uint8)

# %%
alpha = 1.5 
high_boost = src.astype(np.float64) - laplacian
high_boost = np.clip(high_boost * alpha, 0, 255).astype(np.uint8)

# %%
plt.subplot(1,3,1)
plt.imshow(src,cmap='gray')
plt.title('Original Image')

plt.subplot(1,3,2)
plt.imshow(sharpened_image,cmap='gray')
plt.title('laplace Image')

plt.subplot(1,3,3)
plt.imshow(high_boost,cmap='gray')
plt.title('high_boosted Image')
# Out:
# Text(0.5, 1.0, 'high_boosted Image')
